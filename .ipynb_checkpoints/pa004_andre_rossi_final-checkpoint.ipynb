# %% [markdown]
# # Insurance All

# %% [markdown]
# ## Business Problem
#
# Insurance All is a company that provides health insurance to its customers and the product team is analyzing the possibility of offering policyholders a new product: auto insurance.
#
# As with health insurance, customers of this new auto insurance plan need to pay an amount annually to Insurance All to obtain an amount insured by the company, aimed at the costs of an eventual accident or damage to the vehicle.
#
# Insurance All conducted a survey of about 380,000 customers about their interest in joining a new auto insurance product last year. All customers expressed interest or not in purchasing auto insurance and these responses were saved in a database along with other customer attributes.
#
# The product team selected 127 thousand new customers who did not respond to the survey to participate in a campaign, in which they will receive the offer of the new auto insurance product. The offer will be made by the sales team through telephone calls.
#
# However, the sales team has the capacity to make 20 thousand calls within the campaign period.
#
# The challenge
# In that context, it is necessary build a model that predicts whether or not the customer would be interested in auto insurance.
#
# With its solution, the sales team hopes to be able to prioritize the people with the greatest interest in the new product and optimize the campaign by making only contacts with customers most likely to make the purchase.
#
# As a result of the project, it is needed to deliver a report containing some analysis and answers to the following questions:
#
# - Main Insights about the most relevant attributes of customers interested in purchasing auto insurance.
#
# - What percentage of customers interested in purchasing auto insurance will the sales team be able to contact by making 20,000 calls?
#
# - And if the sales team's capacity increases to 40,000 calls, what percentage of customers interested in purchasing auto insurance will the sales team be able to contact?
#
# - How many calls does the sales team need to make to contact 80% of customers interested in purchasing auto insurance?
#
# Link for the business problem: https://sejaumdatascientist.com/como-usar-data-science-para-fazer-a-empresa-vender-mais/

# %% [markdown]
# # Imports

# %%
# database connection
import os
import psycopg2
import pandas.io.sql as psql

# data manipulation
import pandas as pd

# statistics and algebra
import numpy as np
import statistics as st

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# data analysis
from pandas_profiling import ProfileReport

# split dataset
from sklearn.model_selection import train_test_split

# machine learning
from sklearn.dummy          import DummyClassifier
from sklearn.experimental   import enable_hist_gradient_boosting 
from sklearn.ensemble       import HistGradientBoostingClassifier
from sklearn.ensemble       import AdaBoostClassifier
from sklearn.ensemble       import GradientBoostingClassifier
from sklearn.ensemble       import BaggingClassifier
from sklearn.ensemble       import StackingClassifier
from sklearn.ensemble       import RandomForestClassifier
from sklearn.ensemble       import ExtraTreesClassifier
from sklearn.neighbors      import KNeighborsClassifier
from sklearn.linear_model   import LogisticRegression, SGDClassifier
from sklearn.naive_bayes    import GaussianNB
from imblearn.ensemble      import BalancedRandomForestClassifier
from lightgbm               import LGBMClassifier
from catboost               import CatBoostClassifier
from xgboost                import XGBClassifier

# metrics
from scikitplot.metrics import plot_lift_curve, plot_cumulative_gain
from sklearn.metrics import roc_auc_score

#fine tuning
from skopt import forest_minimize

# cross validation
from sklearn.model_selection import StratifiedKFold

# display
from IPython.core.display import HTML
from IPython.display import Image

# save pickle objects
import pickle

# filter warnings
import warnings
warnings.filterwarnings('ignore')

# deploy
import requests

# %% [markdown]
# ## Functions

# %%
###########################################################################################################################

# Descripite Statistics of a Data Frame
def descriptive( df ):
    # Central Tendency - mean, median, mode 
    ct1 = pd.DataFrame( df.apply( np.mean) ).T
    ct2 = pd.DataFrame( df.apply( np.median) ).T
    ct3 = pd.DataFrame( df.apply( st.mode ) ).T 
    
    # Dispersion
    d1 = pd.DataFrame(df.apply(np.std)).T
    d2 = pd.DataFrame(df.apply(min)).T
    d3 = pd.DataFrame(df.apply(max)).T
    d4 = pd.DataFrame(df.apply(lambda x: x.max() - x.min())).T
    d5 = pd.DataFrame(df.apply(lambda x: np.quantile(x, .25))).T
    d6 = pd.DataFrame(df.apply(lambda x: np.quantile(x, .75))).T
    d7 = pd.DataFrame(df.apply(lambda x: x.skew())).T
    d8 = pd.DataFrame(df.apply(lambda x: x.kurtosis())).T

    # Concatenate
    ds = pd.concat([ct1, ct2, ct3, d1, d2, d3, d4, d5, d6, d7, d8]).T.reset_index()
    ds.columns = ['attributes', 'mean', 'median', 'mode', 'std', 'min', 'max', 'range', 'Q1', 'Q3', 'skewness', 'kurtosis']
    return ds

###########################################################################################################################

# Feature Selection
def feature_selection(model, x, y):
    model.fit(x, y)
        
    # Feature importance data frame
    feat_imp = pd.DataFrame({'feature': x.columns,
                             'feature_importance': model.feature_importances_}) \
                             .sort_values('feature_importance', ascending=False) \
                             .reset_index(drop=True)
        
    # Plot feature importance
    plt.figure(figsize=(12,6))
    sns.barplot(x='feature_importance', y='feature', data=feat_imp, orient='h', palette='magma')
    plt.title(type(model).__name__, size=16)
    plt.yticks(size=13)
    plt.xticks(size=13)
    plt.xlabel('Feature Importance', size=16, color='grey')
    plt.ylabel('Features', size=16, color='grey')
    
###########################################################################################################################

# Precision @ K
def precision_at_k( data, k=20000 ):
    data = data.reset_index( drop=True )
    data['ranking'] = data.index + 1 
    data['precision_at_k'] = data['response'].cumsum() / data['ranking']

    return data.loc[k, 'precision_at_k']

###########################################################################################################################

# Recall @ K
def recall_at_k( data, k=20000 ):
    data = data.reset_index( drop=True )
    data['ranking'] = data.index + 1 
    data['recall_at_k'] = data['response'].cumsum() / data['response'].sum()

    return data.loc[k, 'recall_at_k']

###########################################################################################################################

# Metrics @ k
def metrics_at_k (data, model, x_train, y_train, x_val, y_val):
    model_df = []     
    
    for model in model:
        print("Training " + type(model).__name__ + "...")
        model.fit(x_train, y_train)

        yhat = model.predict_proba(x_val)
        data = x_val.copy()
        data['response'] = y_val.copy()
        data['score'] = yhat[:, 1].tolist()
        data = data.sort_values('score', ascending=False)

        precision = precision_at_k(data)
        recall = recall_at_k(data)

        df = pd.DataFrame({'Model Name': type(model).__name__,'Precision@K': precision, 
                           'Recall@K': recall}, index = [0]).sort_values('Precision@K', ascending = False)

        model_df.append(df)
        final_model = pd.concat(model_df)
    return final_model.sort_values(by='Precision@K', ascending=False).round(4)

###########################################################################################################################

# Cross Validation
def cross_validation(model, x_train, y_train, k, data):
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=28)
    precision_list=[]
    recall_list=[]
    i=1

    for train_cv, val_cv in kfold.split(x_train, y_train):
        print(f'Fold Number {i}/{k}')
        x_train_fold = x_train.iloc[train_cv]
        y_train_fold = y_train.iloc[train_cv]
        x_val_fold = x_train.iloc[val_cv]
        y_val_fold = y_train.iloc[val_cv]

        model_fit = model.fit(x_train_fold, y_train_fold)
        yhat = model.predict_proba(x_val_fold)

        data = x_val_fold.copy()
        data['response'] = y_val_fold.copy()
        data['score'] = yhat[:, 1].tolist()
        data = data.sort_values('score', ascending=False)

        precision = precision_at_k(data)
        precision_list.append(precision)
        
        recall = recall_at_k(data)
        recall_list.append(recall)
        
        i+=1
        
    df = pd.DataFrame({'Model Name': type(model).__name__, 
                       'Precision@K Mean': round(np.mean(precision_list), 4),
                       'Precision@K STD': round(np.std(precision_list), 4),
                       'Recall@K Mean': round(np.mean(recall_list), 4),
                       'Recall@K STD': round(np.std(recall_list), 4)}, index = [0])
    
    return df

###########################################################################################################################

# Jupyter Settings
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use('seaborn-whitegrid')
    plt.rcParams['figure.figsize'] = [12,6]
    plt.rcParams['font.size'] = 16
    pd.set_option('display.float_format', lambda x: '%.4f' % x)
    pd.set_option('display.expand_frame_repr', False)
    sns.set()
    
jupyter_settings()
    
###########################################################################################################################
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load Dataset - SQL

# %%
# load enviroment variables
host = os.environ.get('HOST_CDS')
port = os.environ.get('PORT_CDS')
database = os.environ.get('BD_CDS')
user = os.environ.get('USER_CDS')
pwd = os.environ.get('PWD_CDS')

# %% [markdown]
# ## Connect to Database

# %%
# Connect to an existing dataset
conn = psycopg2.connect(user = user,
                        password = pwd,
                        host = host,
                        port = port,
                        database = database)

# %% [markdown]
# ## Check Schemas

# %%
# Create a cursor to perfor database operations
cursor = conn.cursor()

# Take a look at Schemas
query_schema = """
    SELECT nspname
    FROM pg_catalog.pg_namespace
"""
cursor.execute( query_schema )

record = cursor.fetchall()
print( record )
# Out:
# [('pg_toast',), ('pg_temp_1',), ('pg_toast_temp_1',), ('pg_catalog',), ('information_schema',), ('public',), ('pa004',)]

# %% [markdown]
# ## Select Tables

# %%
# Create a cursor to perfor database operations
cursor = conn.cursor()

# Take a look at Schemas
query_tables = """
    SELECT tablename
    FROM  pg_tables
    WHERE schemaname='pa004'
"""
cursor.execute( query_tables )

record = cursor.fetchall()
print( record )
# Out:
# [('users',), ('vehicle',), ('insurance',)]

# %% [markdown]
# ## Check Tables

# %%
# import the tables
df_users = pd.read_sql("SELECT * FROM pa004.users", con=conn)
df_vehicle = pd.read_sql("SELECT * FROM pa004.vehicle", con=conn)
df_insurance = pd.read_sql("SELECT * FROM pa004.insurance", con=conn)

# %%
# close connection
cursor.close()
conn.close()

# %%
# show users dataset
df_users
# Out:
#             id  gender  age  region_code  policy_sales_channel
# 0            1    Male   44      28.0000               26.0000
# 1            2    Male   76       3.0000               26.0000
# 2            3    Male   47      28.0000               26.0000
# 3            4    Male   21      11.0000              152.0000
# 4            5  Female   29      41.0000              152.0000
# ...        ...     ...  ...          ...                   ...
# 381104  381105    Male   74      26.0000               26.0000
# 381105  381106    Male   30      37.0000              152.0000
# 381106  381107    Male   21      30.0000              160.0000
# 381107  381108  Female   68      14.0000              124.0000
# 381108  381109    Male   46      29.0000               26.0000
#
# [381109 rows x 5 columns]

# %%
# show vehicle dataset
df_vehicle
# Out:
#             id  driving_license vehicle_age vehicle_damage
# 0            1                1   > 2 Years            Yes
# 1            2                1    1-2 Year             No
# 2            3                1   > 2 Years            Yes
# 3            4                1    < 1 Year             No
# 4            5                1    < 1 Year             No
# ...        ...              ...         ...            ...
# 381104  381105                1    1-2 Year             No
# 381105  381106                1    < 1 Year             No
# 381106  381107                1    < 1 Year             No
# 381107  381108                1   > 2 Years            Yes
# 381108  381109                1    1-2 Year             No
#
# [381109 rows x 4 columns]

# %%
# show insurance dataset
df_insurance
# Out:
#             id  previously_insured  annual_premium  vintage  response
# 0            1                   0      40454.0000      217         1
# 1            2                   0      33536.0000      183         0
# 2            3                   0      38294.0000       27         1
# 3            4                   1      28619.0000      203         0
# 4            5                   1      27496.0000       39         0
# ...        ...                 ...             ...      ...       ...
# 381104  381105                   1      30170.0000       88         0
# 381105  381106                   1      40016.0000      131         0
# 381106  381107                   1      35118.0000      161         0
# 381107  381108                   0      44617.0000       74         0
# 381108  381109                   0      41777.0000      237         0
#
# [381109 rows x 5 columns]

# %% [markdown]
# ## Raw Data

# %%
# merge all datasets
df_raw = pd.merge( df_users, df_vehicle, how='inner', on='id' )
df_raw = pd.merge( df_raw, df_insurance, how='inner', on='id' )

# %%
# see the dataset
df_raw
# Out:
#             id  gender  age  region_code  policy_sales_channel  driving_license vehicle_age vehicle_damage  previously_insured  annual_premium  vintage  response
# 0            1    Male   44      28.0000               26.0000                1   > 2 Years            Yes                   0      40454.0000      217         1
# 1            2    Male   76       3.0000               26.0000                1    1-2 Year             No                   0      33536.0000      183         0
# 2            3    Male   47      28.0000               26.0000                1   > 2 Years            Yes                   0      38294.0000       27         1
# 3            4    Male   21      11.0000              152.0000                1    < 1 Year             No                   1      28619.0000      203         0
# 4            5  Female   29      41.0000              152.0000                1    < 1 Year             No                   1      27496.0000       39         0
# ...        ...     ...  ...          ...                   ...              ...         ...            ...                 ...             ...      ...       ...
# 381104  381105    Male   74      26.0000               26.0000                1    1-2 Year             No                   1      30170.0000       88         0
# 381105  381106    Male   30      37.0000              152.0000                1    < 1 Year             No                   1      40016.0000      131         0
# 381106  381107    Male   21      30.0000              160.0000                1    < 1 Year             No                   1      35118.0000      161         0
# 381107  381108  Female   68      14.0000              124.0000                1   > 2 Years            Yes                   0      44617.0000       74         0
# 381108  381109    Male   46      29.0000               26.0000                1    1-2 Year             No                   0      41777.0000      237         0
#
# [381109 rows x 12 columns]

# %%
# save the dataset
pickle.dump(df_raw, open('data/df_raw.pkl', 'wb'))

# %%
# empty auxiliary datasets
df_insurance = None
df_users = None
df_vehicle = None

# %% [markdown]
# # Raw Dataset Analysis

# %% [markdown]
# #### Dataset Columns
#
# - Id: Customer ID
# - Gender: Customer Gender
# - Customer Age: Customer Age
# - Region Code: The code of the region that customer lives
# - Policy Sales Channel: The code for the customer disclosure channel (mail, phone, agents, etc.)
# - Driving License: Customer has a license 1; customer has no license 0
# - Vehicle Age: The age of the vehicle
# - Vehicle Damage: If the vehicle has been damaged in the past, yes or no
# - Previously Insured: If the customer has a previous insurance, no: 0, yes: 1
# - Annual Premium: How much the customer paid the company for annual health insurance
# - Vintage: Number of days the customer joined the company through the purchase of health insurance.
# - Response: The customer has interest in buy the car insurance, no: 0, yes: 1
#
# #### The dataset has 381109 rows × 12 columns

# %%
profile = ProfileReport(df_raw, title='Insurance_All') 
profile.to_file(output_file='Insurance_All')

# %% [markdown]
# # Strings to Numerical Columns

# %%
df1 = pickle.load(open('data/df_raw.pkl', 'rb'))

# %%
# label enconding
df1["gender"] = df1["gender"].apply(lambda x: 0 if x == 'Male' else 1).astype(int)
df1["vehicle_damage"] = df1["vehicle_damage"].apply(lambda x: 0 if x == 'No' else 1).astype(int)

# ordinal enconding
df1["vehicle_age"] = df1["vehicle_age"].apply(lambda x: 0 if x == '< 1 Year' else 1 if x == '1-2 Year' else 2).astype(int)

# %%
df1.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel  driving_license  vehicle_age  vehicle_damage  previously_insured  annual_premium  vintage  response
# 0   1       0   44     28.00000              26.00000                1            2               1                   0     40454.00000      217         1
# 1   2       0   76      3.00000              26.00000                1            1               0                   0     33536.00000      183         0
# 2   3       0   47     28.00000              26.00000                1            2               1                   0     38294.00000       27         1
# 3   4       0   21     11.00000             152.00000                1            0               0                   1     28619.00000      203         0
# 4   5       1   29     41.00000             152.00000                1            0               0                   1     27496.00000       39         0

# %%
# save dataset
pickle.dump(df1, open('data/df1.pkl', 'wb'))

# %% [markdown]
# ## According to the Pandas Profile Report the following key points can be highlighted:
#
# -  The data set has no missing cells or duplicate rows
# -  There are more men (54.1%) than women (45.9%)
# -  The age ranges from 20 to 85 years. The average age is 38 years and the distribution is positively skewed (0.67). There is a peak at the ages of 23 and 24, both representing 13.2% of all ages
# -  The most common region code is 28, representing 27.9% of all 53 codes
# -  The most common policy sales channel are 152 (35.4%), 26 (20.9%) and 124 (19.4%)
# -  Most customers have a driver's license (99.8%)
# -  Most vehicles are between 1 and 2 years old (52.6%), followed by vehicles under 1 year old (43.2%) and over 2 years old (4.2%)
# -  Most vehicles were damaged (50.5%)
# -  Most customers have already been assured (54.2%)
# -  The average of annual premium is 30564, in addition to a minimum of 2630 and a maximum of 540165. The distribution is highly skewed (1.76) and has a kurtosis of 34, which implies that there are many outliers and data is concentrated at the beginning of the curve
# -  The target variable (response) is quite unbalanced, since 87.7% of customers answered "no" to a new auto insurance proposal

# %% [markdown]
# # Mind Map

# %%
Image('img/mind_map.jpg')

# %% [markdown]
# # Feature Engineering

# %%
df2 = pickle.load(open('data/df1.pkl', 'rb'))

# %%
# age damage
age_damage = pd.DataFrame(df2.groupby('age')['vehicle_damage'].sum()).reset_index().rename(columns={'vehicle_damage':'age_damage'})
df2 = pd.merge(df2, age_damage, how='left', on='age')

# vintage annual premium
df2['vintage_annual_premium'] = (df2['annual_premium']) / (df2['vintage'])

# age vintage
df2['age_vintage'] = (df2['age']*365) / (df2['vintage'])

# age_damage_premium
df2['age_damage_premium'] = (df2['annual_premium']) / (df2['age_damage'])

# %%
df2.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel  driving_license  vehicle_age  vehicle_damage  previously_insured  annual_premium  vintage  response  age_damage  vintage_annual_premium  age_vintage  age_damage_premium
# 0   1       0   44     28.00000              26.00000                1            2               1                   0     40454.00000      217         1        5771               186.42396     74.00922             7.00988
# 1   2       0   76      3.00000              26.00000                1            1               0                   0     33536.00000      183         0         837               183.25683    151.58470            40.06691
# 2   3       0   47     28.00000              26.00000                1            2               1                   0     38294.00000       27         1        5090              1418.29630    635.37037             7.52338
# 3   4       0   21     11.00000             152.00000                1            0               0                   1     28619.00000      203         0        7324               140.98030     37.75862             3.90756
# 4   5       1   29     41.00000             152.00000                1            0               0                   1     27496.00000       39         0        2504               705.02564    271.41026            10.98083

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381109 entries, 0 to 381108
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      381109 non-null  int64
#  1   gender                  381109 non-null  int64
#  2   age                     381109 non-null  int64
#  3   region_code             381109 non-null  float64
#  4   policy_sales_channel    381109 non-null  float64
#  5   driving_license         381109 non-null  int64
#  6   vehicle_age             381109 non-null  int64
#  7   vehicle_damage          381109 non-null  int64
#  8   previously_insured      381109 non-null  int64
#  9   annual_premium          381109 non-null  float64
#  10  vintage                 381109 non-null  int64
#  11  response                381109 non-null  int64
#  12  age_damage              381109 non-null  int64
#  13  vintage_annual_premium  381109 non-null  float64
#  14  age_vintage             381109 non-null  float64
#  15  age_damage_premium      381109 non-null  float64
# dtypes: float64(6), int64(10)
# memory usage: 49.4 MB

# %%
pickle.dump(df2, open( 'data/df2.pkl', 'wb' ) )

# %% [markdown]
# # Exploratory Data Analysis - Insight Generation

# %%
df3 = pickle.load(open('data/df2.pkl', 'rb'))

# %% [markdown]
# ## Univariate Analysis

# %%
df3.hist(bins=35, figsize=(22,12));

# %%
aux = df3[['age', 'annual_premium', 'vintage', 'age_damage', 'vintage_annual_premium', 'age_vintage', 'age_damage_premium']]
descriptive(aux)
# Out:
#                attributes        mean      median       mode         std        min          max        range          Q1          Q3  skewness    kurtosis
# 0                     age    38.82258    36.00000   24.00000    15.51159   20.00000     85.00000     65.00000    25.00000    49.00000   0.67254    -0.56566
# 1          annual_premium 30564.38958 31669.00000 2630.00000 17213.13247 2630.00000 540165.00000 537535.00000 24405.00000 39400.00000   1.76609    34.00457
# 2                 vintage   154.34740   154.00000  256.00000    83.67119   10.00000    299.00000    289.00000    82.00000   227.00000   0.00303    -1.20069
# 3              age_damage  4340.27836  4322.00000 6659.00000  1899.27119    2.00000   7324.00000   7322.00000  2600.00000  5845.00000   0.06601    -1.20221
# 4  vintage_annual_premium   363.74043   194.75234   15.20231   548.65240    8.79599  33717.28571  33708.48973   117.32028   374.18898   5.74146   107.70986
# 5             age_vintage   168.58202    91.87075  365.00000   230.41671   24.41472   2920.00000   2895.58528    56.47170   172.89474   4.11085    23.01507
# 6      age_damage_premium    10.61947     6.99411    0.39495   117.95895    0.35909  27663.00000  27662.64091     4.18640    11.65038 168.26877 33237.54538

# %% [markdown]
# ### Response Variable

# %%
plt.figure(figsize=(12,5))
ax = sns.countplot(y='response', data=df3, palette='magma')
sns.set_style('whitegrid')
plt.title('Response Variable', size =20)
plt.xlabel('', color='white')
plt.ylabel('', color='white');
sns.despine( bottom=True, left=True)
total = df3['response'].size
for p in ax.patches:
        percentage = ' {:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

# %% [markdown]
# ## Bivariate Analysis  (Hypothesis Test - Insight Generation)

# %% [markdown]
# ### Hypothesis List

# %% [markdown]
# ### H1 - Older customers are more likely to take out a car insurance
# ### H2 - Women are more likely to take out a car insurance
# ### H3 - Customers with older cars are more likely to take out a car insurance
# ### H4 - Customers previously insured are more likely to take out a car insurance
# ### H5 - Customers with previously damaged cars are more likely to take out a car insurance
# ### H6 - Customers with higher annual premium are more likely to take out a car insurance

# %% [markdown]
# ## H1 - Older customers are more likely to take out a car insurance
#
# #### False - People between 40 and 50 are more likely to take out a car insurance

# %%
aux1 = df3[df3['response'] == 1 ][['response', 'age']].groupby(['age']).sum().reset_index()

bins = list( np.arange( 20, 90, 5) )
aux2 = aux1
aux2['age_bin'] = pd.cut(aux1['age'], bins=bins)
aux3 = aux2[['response', 'age_bin']].groupby(['age_bin']).sum().reset_index()

plt.figure(figsize(20,8))
plt.subplot(121)
sns.barplot(x='age_bin', y='response', data=aux3, palette='magma')
sns.despine(bottom=True, left=True)
sns.set_style('whitegrid')
plt.title('Age by Response', size=20)
plt.xlabel('Age', color='grey', size=15)
plt.ylabel('Response', color='grey', size=15);
plt.xticks(rotation=75)

plt.subplot(122)
sns.heatmap( aux2.corr( method='pearson' ), annot=True, cmap="magma" )
sns.despine( bottom = True, left = True)
plt.title( 'Age by Response', size=20)
plt.xticks(size = 15)
plt.yticks(size = 15);

# %% [markdown]
# ## H2 - Women are more likely to take out a car insurance
#
# #### False - Women are not more likely to take out a car insurance

# %%
plt.figure(figsize(20,8))
plt.subplot(121)
aux1 = df3[df3['response'] == 1 ]

ax = sns.countplot(y='gender', data=aux1, palette='magma')
sns.set_style('whitegrid')
plt.title('Gender', size =20)
plt.yticks(np.arange(2), ['Men', 'Women'], size = 15)
plt.xlabel('', color='white')
plt.ylabel('', color='white');
sns.despine( bottom=True, left=True)
total = aux1['response'].size
for p in ax.patches:
        percentage = ' {:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.subplot(122)
aux2= aux1[['response', 'age']].groupby(['age']).sum().reset_index()
sns.heatmap( aux2.corr( method='pearson' ), annot=True, cmap="magma")
sns.despine( bottom = True, left = True)
plt.title( 'Gender by Response', size=20)
plt.xticks(size = 15)
plt.yticks(size = 15);

# %% [markdown]
# ## H3 - Customers with older cars are more likely to take out a car insurance
#
# #### False - Customers with cars between 1 and 2 years are more likely to take out a car insurance

# %%
plt.figure(figsize(20,8))
plt.subplot(121)
aux1 = df3[df3['response'] == 1 ]

ax = sns.countplot(y='vehicle_age', data=aux1, palette='magma')
sns.set_style('whitegrid')
plt.title('Vehicle Age by Response', size=20)
plt.yticks(np.arange(3), ['< Year', '1-2 Years', '> 2 Years'], size = 15)
plt.xlabel('', color='white')
plt.ylabel('', color='white');
sns.despine( bottom=True, left=True)
total = aux1['response'].size
for p in ax.patches:
        percentage = ' {:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
        
plt.subplot(122)
aux2= aux1[['response', 'vehicle_age']].groupby(['vehicle_age']).sum().reset_index()
sns.heatmap( aux2.corr( method='pearson' ), annot=True, cmap="magma")
sns.despine( bottom = True, left = True)
plt.title( 'Vehicle Age by Response', size=20)
plt.xticks(size = 15)
plt.yticks(size = 15);

# %% [markdown]
# ## H4 - Customers previously insured are more likely to take out a car insurance
#
# #### True - Customers previously insured are more likely to take out a car insurance

# %%
plt.figure(figsize=(12,5))
aux1 = df3[df3['response'] == 1 ]

ax = sns.countplot(y='previously_insured', data=aux1, palette='magma')
sns.set_style('whitegrid')
plt.title('Previously Insured by Response', size = 20)
plt.yticks(np.arange(2), ['Insured', 'Uninsured'], size = 15)
plt.xlabel('', color='white')
plt.ylabel('', color='white');
sns.despine( bottom=True, left=True)
total = aux1['response'].size
for p in ax.patches:
        percentage = ' {:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

# %% [markdown]
# ## H5 - Customers with previously damaged cars are more likely to take out a car insurance
#
# #### True - Customers with previously damaged cars are more likely to take out a car insurance

# %%
plt.figure(figsize=(12,5))
aux1 = df3[df3['response'] == 1 ]

ax = sns.countplot(y='vehicle_damage', data=aux1, palette='magma')
sns.set_style('whitegrid')
plt.title('Vehicle Damaged by Response', size = 20)
plt.yticks(np.arange(2), ['Damaged', 'Undamaged'], size = 15)
plt.xlabel('', color='white')
plt.ylabel('', color='white');
sns.despine( bottom=True, left=True)
total = aux1['response'].size
for p in ax.patches:
        percentage = ' {:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

# %% [markdown]
# ## H6 - Customers with higher annual premium are more likely to take out a car insurance
#
# #### False - Customers with lower annual premium are more likely to take out a car insurance

# %%
plt.figure(figsize(20,8))
plt.subplot(121)
sns.kdeplot(x='annual_premium', data=df3, hue='response', multiple="stack")
plt.title( 'Annual Premium by Response', size=20);

plt.subplot(122)
aux2= aux1[['response', 'annual_premium']].groupby(['annual_premium']).sum().reset_index()
sns.heatmap( aux2.corr( method='pearson' ), annot=True, cmap="magma")
sns.despine( bottom = True, left = True)
plt.title( 'Annual Premium by Response', size=20)
plt.xticks(size = 15)
plt.yticks(size = 15);

# %% [markdown]
# # Multivariate Analisys

# %% [markdown]
# ## Pearson Correlation - Numeraical Features

# %%
# correlation
corr = df3[['age', 'region_code', 'policy_sales_channel', 'vehicle_age', 
                   'annual_premium', 'vintage', 'age_damage', 'vintage_annual_premium',
                   'age_vintage', 'age_damage_premium', 'response']].corr(method='pearson')

# Creating a with mask for the superior triangle
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    # Creating the chart with mask
    plt.figure(figsize(18,12))
    ax = sns.heatmap(corr, mask=mask, annot = True, cmap = 'magma')
    plt.xticks(size = 14, rotation=70)
    plt.yticks(size = 14)
    plt.title("Pearson Correlation of Numerical Variables", size=20);

# %% [markdown]
# ## Cramer's V (Pandas Profiling)

# %%
profile = ProfileReport(df3, title='Insurance All 2') 
profile.to_file(output_file='Insurance_All_2')

# %%
# Cramer's V
Image('img/cramer.png')

# %%
pickle.dump(df3, open('data/df3.pkl', 'wb'))

# %% [markdown]
# # Split into train (60%), validation (20%), test (20%)
#
# The decision behind this division was motivated by the problem. To have a fair comparison between the test and validation sets they must be the same size, since the precision at k and recall at k depends on the amount of data.

# %%
# load data
df4 = pickle.load(open('data/df3.pkl', 'rb'))

# select features and target variable
X = df4.drop(df4[['response', 'id']], axis=1)
y = df4['response'].copy()

# train test split
X_train, x_test, Y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=28, shuffle=True)

# train valid split
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=28, shuffle=True)

df4 = pd.concat([x_train, y_train], axis=1)

# check balance of classes (0, 1) among y_train, y_test and y_valid
print(f"y_train size: {np.bincount(y_train)}")
print(f"y_test size: {np.bincount(y_test)}")
print(f"y_valid size: {np.bincount(y_val)}")

# shape of trains, tests and vals
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# y_train size: [200634  28031]
# y_test size: [66801  9421]
# y_valid size: [66964  9258]
# (228665, 14)
# (76222, 14)
# (76222, 14)
# (228665,)
# (76222,)
# (76222,)

# %%
# saving all data
pickle.dump(x_train, open('data/x_train.pkl', 'wb'))
pickle.dump(x_test, open('data/x_test.pkl', 'wb'))
pickle.dump(x_val, open('data/x_valy_val.pkl', 'wb'))

pickle.dump(y_train, open('data/y_train.pkl', 'wb'))
pickle.dump(y_test, open('data/y_test.pkl', 'wb'))
pickle.dump(y_val, open('data/y_val.pkl', 'wb'))

pickle.dump(df4, open('data/df4.pkl', 'wb'))

# %% [markdown]
# # Data Preparation

# %%
df5 = pickle.load(open('data/df4.pkl', 'rb'))

# %% [markdown]
# ## Reescaling

# %%
df5.hist(bins=35, figsize=(18,12));

# %%
# # scalers
# mms = MinMaxScaler()

# # age - min-max
# df5['age'] = mms.fit_transform(df5[['age']].values)

# # annual premium - robust
# df5['annual_premium'] = mms.fit_transform(df5[['annual_premium']].values)

# # age damage - min-max 
# df5['age_damage'] = mms.fit_transform(df5[['age_damage']].values)

# # vintage annual premium - robust
# df5['vintage_annual_premium'] = mms.fit_transform(df5[['vintage_annual_premium']].values)

# # age vintage - robust
# df5['age_vintage'] = mms.fit_transform(df5[['age_vintage']].values)

# # age damage premium - robust
# df5['age_damage_premium'] = mms.fit_transform(df5[['age_damage_premium']].values)

# %% [markdown]
# ## Validation Preparation

# %%
# # age
# x_val.loc[:,'age'] = mms.fit_transform(x_val[['age']].values)

# # annual premium
# x_val.loc[:,'annual_premium'] = mms.fit_transform(x_val[['annual_premium']].values)

# # age damage
# x_val.loc[:,'age_damage'] = mms.fit_transform(x_val[['age_damage']].values)

# # vintage annual premium
# x_val.loc[:,'vintage_annual_premium'] = mms.fit_transform(x_val[['vintage_annual_premium']].values)

# # age vintage
# x_val.loc[:,'age_vintage'] = mms.fit_transform(x_val[['age_vintage']].values)

# # age damage premium
# x_val.loc[:,'age_damage_premium'] = mms.fit_transform(x_val[['age_damage_premium']].values)

# %% [markdown]
# ### After several tests it was concluded that there is no difference in performance using data preparation.
# ### It was decided not to use data preparation to simplify the model deployment

# %%
pickle.dump(df5, open('data/df5.pkl', 'wb'))

# %% [markdown]
# # Feature Selection

# %%
# load data
df6 = pickle.load(open('data/df5.pkl', 'rb'))
# x = df5.drop(['response'], axis=1).copy()
# y = df5['response'].copy()

# %% [markdown]
# ## Random Forest

# %%
# # classifier
# rf = RandomForestClassifier(n_jobs=-1)
# feature_selection(rf, x, y)

# %% [markdown]
# ### After several tests, it was concluded that the performance of the models worsens if feature selection is performed

# %%
pickle.dump(df6, open('data/df6.pkl', 'wb'))

# %% [markdown]
# # Machine Learning

# %%
# load data
x_train = pickle.load(open('data/x_train.pkl', 'rb'))
y_train = pickle.load(open('data/y_train.pkl', 'rb'))
x_val = pickle.load(open('data/x_val.pkl', 'rb'))
y_val = pickle.load(open('data/y_val.pkl', 'rb'))
df7 = pickle.load(open('data/df6.pkl', 'rb'))

# %%
# estimators for stacking classifier
estimators = [('lgbm', LGBMClassifier(n_jobs=-1)),
              ('xgb', XGBClassifier(verbosity=0))]

# models
model=[AdaBoostClassifier(),
       GradientBoostingClassifier(),
       BaggingClassifier(base_estimator=LGBMClassifier(n_jobs=-1)),
       StackingClassifier(estimators=estimators, final_estimator=LGBMClassifier(n_jobs=-1)),
       HistGradientBoostingClassifier(),
       CatBoostClassifier(verbose=False),
       XGBClassifier(verbosity=0),
       LGBMClassifier(n_jobs=-1),
       LogisticRegression(),
       RandomForestClassifier(),
       ExtraTreesClassifier(),
       BalancedRandomForestClassifier(),
       KNeighborsClassifier(n_jobs=-1),
       SGDClassifier(loss='log', n_jobs=-1), 
       GaussianNB(),
       DummyClassifier()]

metrics_at_k(df7, model, x_train, y_train, x_val, y_val)
# Out:
# Training AdaBoostClassifier...
# Training GradientBoostingClassifier...
# Training BaggingClassifier...
# Training StackingClassifier...
# Training HistGradientBoostingClassifier...
# Training CatBoostClassifier...
# Training XGBClassifier...
# Training LGBMClassifier...
# Training LogisticRegression...
# Training RandomForestClassifier...
# Training ExtraTreesClassifier...
# Training BalancedRandomForestClassifier...
# Training KNeighborsClassifier...
# Training SGDClassifier...
# Training GaussianNB...
# Training DummyClassifier...
#                        Model Name  Precision@K  Recall@K
# 0              AdaBoostClassifier       0.2981    0.6441
# 0      GradientBoostingClassifier       0.2958    0.6390
# 0               BaggingClassifier       0.2881    0.6225
# 0  BalancedRandomForestClassifier       0.2856    0.6171
# 0                  LGBMClassifier       0.2843    0.6142
# 0              StackingClassifier       0.2817    0.6086
# 0            ExtraTreesClassifier       0.2770    0.5984
# 0                      GaussianNB       0.2763    0.5970
# 0  HistGradientBoostingClassifier       0.2761    0.5965
# 0                   XGBClassifier       0.2687    0.5806
# 0              CatBoostClassifier       0.2635    0.5692
# 0          RandomForestClassifier       0.2507    0.5417
# 0              LogisticRegression       0.1829    0.3952
# 0            KNeighborsClassifier       0.1199    0.2591
# 0                   SGDClassifier       0.1199    0.2591
# 0                 DummyClassifier       0.1199    0.2591

# %% [markdown]
# ## Cross Validation of Best Models

# %% [markdown]
# ### Adaboost

# %%
cross_validation(AdaBoostClassifier(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#            Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  AdaBoostClassifier            0.2675           0.0012         0.9543        0.0043

# %% [markdown]
# ### Gradient Boosting

# %%
cross_validation(GradientBoostingClassifier(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#                    Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  GradientBoostingClassifier            0.2678           0.0013         0.9555        0.0046

# %% [markdown]
# ### Hist Gradient Boosting

# %%
cross_validation(HistGradientBoostingClassifier(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#                        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  HistGradientBoostingClassifier            0.2678           0.0013         0.9554        0.0045

# %% [markdown]
# ### LGBM

# %%
# cross validation lgbm
cross_validation(LGBMClassifier(n_jobs=-1), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  LGBMClassifier            0.2681           0.0014         0.9565        0.0048

# %% [markdown]
# ### Stacking

# %%
# estimators
estimators = [('lgbm', LGBMClassifier(n_jobs=-1)),
              ('xgb', XGBClassifier(verbosity=0))]

# cross validation extra trees
cross_validation(StackingClassifier(estimators=estimators, final_estimator=LGBMClassifier(random_state=28)), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#            Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  StackingClassifier            0.2679           0.0012         0.9559        0.0043

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
# cross validation 
cross_validation(GaussianNB(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#    Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  GaussianNB            0.2553           0.0022         0.9107        0.0078

# %% [markdown]
# ### Balanced Random Forest

# %%
# cross validation 
cross_validation(BalancedRandomForestClassifier(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#                        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  BalancedRandomForestClassifier            0.2663           0.0014         0.9501        0.0049

# %% [markdown]
# ### Extra Trees

# %%
# cross validation 
cross_validation(ExtraTreesClassifier(), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#              Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  ExtraTreesClassifier            0.2592           0.0014         0.9249        0.0048

# %% [markdown]
# ### Bagging

# %%
# models
model = BaggingClassifier(base_estimator=LGBMClassifier(n_jobs=-1))

# cross validation 
cross_validation(model, x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#           Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  BaggingClassifier            0.2681           0.0013         0.9565        0.0046

# %% [markdown]
# ### XGBoost

# %%
# cross validation xgboost
cross_validation(XGBClassifier(verbosity=0), x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#       Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  XGBClassifier            0.2676           0.0014         0.9547        0.0050

# %% [markdown]
# ### Bagging, LGBM, Hist Gradient Boosting and XGBoost are the best models

# %%
pickle.dump(df7, open('data/df7.pkl', 'wb'))

# %% [markdown]
# ## Lift and Gain Curves

# %% [markdown]
# ### Bagging

# %%
# models
model = BaggingClassifier(base_estimator=LGBMClassifier(random_state=28, n_jobs=-1), random_state=28)
model.fit(x_train, y_train)

# probabilities prediction
yhat_model = model.predict_proba(x_val)

# Cumulative Gain
plot_cumulative_gain(y_val, yhat_model);

# Lift Curve
plot_lift_curve( y_val, yhat_model );

# %% [markdown]
# ### LGBM

# %%
# model
model = LGBMClassifier(random_state=28, n_jobs=-1)
model.fit(x_train, y_train)

# probabilities prediction
yhat_model = model.predict_proba(x_val)

# Cumulative Gain
plot_cumulative_gain(y_val, yhat_model);

# Lift Curve
plot_lift_curve( y_val, yhat_model );

# %% [markdown]
# ### Hist Gradient Boosting (HGB)

# %%
# model
model = HistGradientBoostingClassifier(random_state=28)
model.fit(x_train, y_train)

# probabilities prediction
yhat_model = model.predict_proba(x_val)

# Cumulative Gain
plot_cumulative_gain(y_val, yhat_model);

# Lift Curve
plot_lift_curve( y_val, yhat_model );

# %% [markdown]
# ### XGBoost

# %%
# fit model
model = XGBClassifier(random_state=28, verbosity=0)
model.fit(x_train, y_train)

# probabilities prediction
yhat_model = model.predict_proba(x_val)

# Cumulative Gain
plot_cumulative_gain(y_val, yhat_model);

# Lift Curve
plot_lift_curve(y_val, yhat_model);

# %% [markdown]
# ### LGBM, HGB and XGBoost were chosen as the best models

# %% [markdown]
# # Hyperparameter Optimization

# %% [markdown]
# ## LGBM - Forest Minimizer

# %%
def tune_model(params):
    max_depth = params[0]               
    num_leaves = params[1]              
    min_data_in_leaf = params[2]        
    learning_rate = params[3]           
    colsample_bytree = params[4]        
    n_estimators = params[5]            
    min_child_weight = params[6]        
    
    # model
    model = LGBMClassifier(max_depth=max_depth, 
                           num_leaves=num_leaves, 
                           min_data_in_leaf=min_data_in_leaf,   
                           learning_rate=learning_rate, 
                           colsample_bytree=colsample_bytree, 
                           n_estimators=n_estimators,
                           min_child_weight=min_child_weight, 
                           random_state=28).fit(x_train, y_train)
    
    yhat = model.predict(x_val)
    yhat_proba = model.predict_proba(x_val)[:,1]
    roc_auc = roc_auc_score(y_val, yhat_proba)
    
    return -roc_auc


space = [(2,10), # max_depth
        (4,1024), # num_leaves
        (10,1000), # min_data_in_leaf
        (0.001,0.07), # learning_rate
        (0.1,1), # colsample_bytree
        (10, 100), # n_estimators
        (0.0001, 100)] # min_child_weight

result = forest_minimize(tune_model, space, random_state=28, n_random_starts=20, n_calls=20, verbose=0)
result_list = result.x
result_list
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=42, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=42
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# [LightGBM] [Warning] min_data_in_leaf is set=55, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=55
# [LightGBM] [Warning] min_data_in_leaf is set=119, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=119
# [LightGBM] [Warning] min_data_in_leaf is set=170, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=170
# [LightGBM] [Warning] min_data_in_leaf is set=724, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=724
# [LightGBM] [Warning] min_data_in_leaf is set=647, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=647
# [LightGBM] [Warning] min_data_in_leaf is set=652, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=652
# [LightGBM] [Warning] min_data_in_leaf is set=966, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=966
# [LightGBM] [Warning] min_data_in_leaf is set=798, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=798
# [LightGBM] [Warning] min_data_in_leaf is set=670, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=670
# [LightGBM] [Warning] min_data_in_leaf is set=692, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=692
# [LightGBM] [Warning] min_data_in_leaf is set=53, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=53
# [LightGBM] [Warning] min_data_in_leaf is set=936, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=936
# [LightGBM] [Warning] min_data_in_leaf is set=901, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=901
# [LightGBM] [Warning] min_data_in_leaf is set=343, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=343
# [LightGBM] [Warning] min_data_in_leaf is set=915, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=915
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] min_data_in_leaf is set=296, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=296
# [LightGBM] [Warning] min_data_in_leaf is set=219, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=219
# [LightGBM] [Warning] min_data_in_leaf is set=446, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=446
# [7, 780, 162, 0.05789077876441725, 0.6181785156833446, 98, 97.07951305751159]

# %%
# fit model
lgbm = LGBMClassifier(max_depth=7, 
                      num_leaves=780, 
                      min_data_in_leaf=162,
                      learning_rate=0.058, 
                      colsample_bytree=0.618, 
                      n_estimators=98,
                      min_child_weight=97, 
                      random_state=28,
                      n_jobs=-1)

# cross validation lgbm
cross_validation(lgbm, x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 2/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 3/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 4/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 5/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
#        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  LGBMClassifier           0.26820          0.00110        0.95670       0.00390

# %% [markdown]
# ## HGB - Forest Minimizer

# %%
def tune_model(params):
    learning_rate = params[0]               
    max_iter = params[1]              
    max_leaf_nodes = params[2]        
    max_depth = params[3]           
    min_samples_leaf = params[4]      
    
    # model
    model = HistGradientBoostingClassifier(learning_rate=learning_rate, 
                                           max_iter=max_iter, 
                                           max_leaf_nodes=max_leaf_nodes, 
                                           max_depth=max_depth, 
                                           min_samples_leaf=min_samples_leaf, 
                                           random_state=28).fit(x_train, y_train)
    
    yhat = model.predict(x_val)
    yhat_proba = model.predict_proba(x_val)[:,1]
    roc_auc = roc_auc_score(y_val, yhat_proba)
    
    return -roc_auc


space = [(0.001,0.07), # learning_rate
        (10,1000), # max_iter
        (10,100), # max_leaf_nodes
        (3,12), # max_depth
        (10,1000)] # min_samples_leaf

result = forest_minimize(tune_model, space, random_state=28, n_random_starts=20, n_calls=20, verbose=0)
result_list = result.x
result_list
# Out:
# [0.033837131403663366, 864, 12, 3, 966]

# %%
# fit model
model = HistGradientBoostingClassifier(learning_rate=0.033, 
                                       max_iter=864, 
                                       max_leaf_nodes=12, 
                                       max_depth=3, 
                                       min_samples_leaf=966, 
                                       random_state=28)

# cross validation lgbm
cross_validation(model, x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#                        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  HistGradientBoostingClassifier           0.26830          0.00130        0.95730       0.00460

# %% [markdown]
# ## XGBoost - Forest Minimizer

# %%
def tune_model(params):
    n_estimators = params[0]
    eta = params[1]
    max_depth = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
        
    
    # model
    model = XGBClassifier(n_estimators=n_estimators, 
                          eta=eta, 
                          max_depth=max_depth,   
                          subsample=subsample, 
                          colsample_bytree=colsample_bytree,
                          random_state=28, 
                          verbosity=0).fit(x_train, y_train)
    
    yhat = model.predict(x_val)
    yhat_proba = model.predict_proba(x_val)[:,1]
    roc_auc = roc_auc_score(y_val, yhat_proba)
    
    return -roc_auc


space = [(10,100), # n_estimators
        (0.01,0.03), # eta
        (3,9), # max_depth
        (0.01,0.07), # subsample
        (0.3,0.9)] # colsample_bytree

result = forest_minimize(tune_model, space, random_state=28, n_random_starts=20, n_calls=20, verbose=0)
result_list = result.x
result_list
# Out:
# [84, 0.02910292868635174, 5, 0.058929214230401566, 0.5855402730753336]

# %%
# fit model
xgb = XGBClassifier(n_estimators=84, 
                       eta=0.029, 
                       max_depth=5,
                       subsample=0.059, 
                       colsample_bytree=0.585,
                       random_state=28, 
                       verbosity=0)

# cross validation xgboost
cross_validation(lgbm, x_train, y_train, 5, df7)
# Out:
# Fold Number 1/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 2/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 3/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 4/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
# Fold Number 5/5
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
#        Model Name  Precision@K Mean  Precision@K STD  Recall@K Mean  Recall@K STD
# 0  LGBMClassifier           0.26820          0.00110        0.95670       0.00390

# %% [markdown]
# ### Unfortunately, hyperparameter optimization has not improved the models.

# %% [markdown]
# # Test Data Performance

# %% [markdown]
# ## Load Data

# %%
x_test = pickle.load(open('data/x_test.pkl', 'rb'))
y_test = pickle.load(open('data/y_test.pkl', 'rb'))
x_train = pickle.load(open('data/x_train.pkl', 'rb'))
y_train = pickle.load(open('data/y_train.pkl', 'rb'))
df7 = pickle.load(open('data/df7.pkl', 'rb'))

# %% [markdown]
# ## Testing Performance

# %% [markdown]
# ### HGB Tuned

# %%
model=[HistGradientBoostingClassifier(learning_rate=0.033, 
                                       max_iter=864, 
                                       max_leaf_nodes=12, 
                                       max_depth=3, 
                                       min_samples_leaf=966, 
                                       random_state=28)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training HistGradientBoostingClassifier...
#                        Model Name  Precision@K  Recall@K
# 0  HistGradientBoostingClassifier      0.33490   0.71110

# %% [markdown]
# ### HGB Default

# %%
model=[HistGradientBoostingClassifier(random_state=28)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training HistGradientBoostingClassifier...
#                        Model Name  Precision@K  Recall@K
# 0  HistGradientBoostingClassifier      0.33610   0.71360

# %% [markdown]
# ### LGBM Tuned

# %%
model=[LGBMClassifier(max_depth=7, 
                      num_leaves=780, 
                      min_data_in_leaf=162,
                      learning_rate=0.058, 
                      colsample_bytree=0.618, 
                      n_estimators=98,
                      min_child_weight=97, 
                      random_state=28,
                      n_jobs=-1)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training LGBMClassifier...
# [LightGBM] [Warning] min_data_in_leaf is set=162, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=162
#        Model Name  Precision@K  Recall@K
# 0  LGBMClassifier      0.33600   0.71330

# %% [markdown]
# ### LGBM Default

# %%
model=[LGBMClassifier(random_state=28, n_jobs=-1)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training LGBMClassifier...
#        Model Name  Precision@K  Recall@K
# 0  LGBMClassifier      0.33660   0.71470

# %% [markdown]
# ### XGBoost Tuned

# %%
model=[XGBClassifier(n_estimators=84, 
                     eta=0.029, 
                     max_depth=5,
                     subsample=0.059, 
                     colsample_bytree=0.585,
                     random_state=28, 
                     verbosity=0)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training XGBClassifier...
#       Model Name  Precision@K  Recall@K
# 0  XGBClassifier      0.33000   0.70070

# %% [markdown]
# ### XGBoost Default

# %%
model=[XGBClassifier(random_state=28, verbosity=0)]

metrics_at_k(df7, model, x_train, y_train, x_test, y_test)
# Out:
# Training XGBClassifier...
#       Model Name  Precision@K  Recall@K
# 0  XGBClassifier      0.33360   0.70820

# %% [markdown]
# ### The default models were chosen as the best models

# %% [markdown]
# ## Gain and Lift Curves

# %% [markdown]
# ### LGBM

# %%
# fit model
lgbm = LGBMClassifier(random_state=28, n_jobs=-1)

lgbm.fit(x_train, y_train)

# probabilities prediction
yhat_lgbm = lgbm.predict_proba(x_test)

# Cumulative Gain
plot_cumulative_gain(y_test, yhat_lgbm);

# Lift Curve
plot_lift_curve(y_test, yhat_lgbm);

# %% [markdown]
# ### HGB

# %%
# fit model
hgb = HistGradientBoostingClassifier(random_state=28)

hgb.fit(x_train, y_train)

# probabilities prediction
yhat_hgb = hgb.predict_proba(x_test)

# Cumulative Gain
plot_cumulative_gain(y_test, yhat_hgb);

# Lift Curve
plot_lift_curve(y_test, yhat_hgb);

# %% [markdown]
# ### XGBoost

# %%
# fit model
xgb = XGBClassifier(random_state=28, verbosity=0)
xgb.fit(x_train, y_train)

# probabilities prediction
yhat_xgb = xgb.predict_proba(x_test)

# Cumulative Gain
plot_cumulative_gain(y_test, yhat_xgb);

# Lift Curve
plot_lift_curve(y_test, yhat_xgb);

# %% [markdown]
# ### Based on the curves LGBM was chosen as the best overall model

# %% [markdown]
# # Business Questions

# %% [markdown]
# ### Obs: To answer the business questions it was chosen the test dataset as a reference

# %% [markdown]
# ## 1 - The most relevant attributes of customers interested in purchasing auto insurance.
# - Age (Customers around 40 and 50 years old)
# - Vehicle Age (Customers with cars between 1 and 2 years)
# - Customers Previously Insured
# - Customers with Previously Damaged Car

# %% [markdown]
# ## 2 - What percentage of customers interested in purchasing auto insurance will the sales team be able to contact by making 20,000 calls?

# %%
# answering the question
print(f'By making 20.000 calls the interested customers percentage is {round(100*20000 / len(df_test),1)}%')
# Out:
# By making 20.000 calls the interested customers percentage is 15.7%

# %%
# using x_test as a reference
lgbm = LGBMClassifier(random_state=28, n_jobs=-1)
lgbm.fit(x_train, y_train)
yhat_lgbm = lgbm.predict_proba(x_test)
plot_lift_curve(y_test, yhat_lgbm)
plt.style.use('seaborn-whitegrid')
plt.axvline(0.157, 0, 1, color='red', ls='--', lw=3);

# %% [markdown]
# ### By making 20,000 calls, the model can predict almost three times better than a random choice (x_test reference).

# %% [markdown]
# ## 3 - If the sales team's capacity increases to 40,000 calls, what percentage of customers interested in purchasing auto insurance will the sales team be able to contact?

# %%
# answering the question
print(f'By making 40.000 calls the interested customers percentage is {round(100*40000 / len(df_test), 1)}%')
# Out:
# By making 40.000 calls the interested customers percentage is 31.5%

# %%
# using x_test as a reference
lgbm = LGBMClassifier(random_state=28, n_jobs=-1)
lgbm.fit(x_train, y_train)
yhat_lgbm = lgbm.predict_proba(x_test)
plot_lift_curve(y_test, yhat_lgbm)
plt.axvline(0.315, 0, 1, color='red', ls='--', lw=3);

# %% [markdown]
# ### By making 40,000 calls, the model can predict more than two and a half times better than a random choice (x_test reference).

# %% [markdown]
# ## 4 - How many calls does the sales team need to make to contact 80% of customers interested in purchasing auto insurance?

# %%
# using x_test dataset as a reference
print(f'To contact 80% of interested customers, the sales team needs {round((80*len(df_test) / 100))} calls')
# Out:
# To contact 80% of interested customers, the sales team needs 101630 calls

# %% [markdown]
# ### But only 50% of the base is necessary to contact almost all interested costumers (x_test reference)

# %%
# using x_test as a reference
lgbm = LGBMClassifier(random_state=28, n_jobs=-1)
lgbm.fit(x_train, y_train)
yhat_lgbm = lgbm.predict_proba(x_test)
plot_cumulative_gain(y_test, yhat_lgbm)
plt.axvline(0.5, 0, 1, color='red', ls='--', lw=3);

# %% [markdown]
# # Test Dataset Predictions

# %%
# load data
pickle.load(open('data/df_test.pkl', 'rb'))

# lgbm
model = LGBMClassifier(random_state=28, n_jobs=-1)

model.fit(x_train, y_train)
yproba = model.predict_proba(df_test)[:, 1]
ypred = model.predict(df_test)

# add probablity and response columns
df_test['probability'] = yproba.copy()
df_test['response'] = ypred.copy()
df_test = df_test.sort_values('probability', ascending=False)

# 10 first rows of dataset
df_test.head(10)
# Out:
#        gender  age  driving_license  region_code  previously_insured  vehicle_age  vehicle_damage  annual_premium  policy_sales_channel  vintage  age_damage  vintage_annual_premium  age_vintage  age_damage_premium  probability  response
# 73350       1   22                1      37.0000                   1            2               1      27536.0000              152.0000      238        7094                115.6975      33.7395              3.8816       0.7416         1
# 60218       1   22                1      30.0000                   0            2               1      27865.0000              152.0000      238        7094                117.0798      33.7395              3.9280       0.7416         1
# 59303       1   22                1      46.0000                   1            2               1      27241.0000              152.0000      238        7094                114.4580      33.7395              3.8400       0.7416         1
# 23275       1   26                1      41.0000                   1            2               1      28548.0000              152.0000      238        4535                119.9496      39.8739              6.2950       0.7297         1
# 16826       1   26                1      36.0000                   1            2               1      29945.0000              152.0000      238        4535                125.8193      39.8739              6.6031       0.6648         1
# 27519       1   21                1      13.0000                   0            2               1      16415.0000              152.0000      135        5453                121.5926      56.7778              3.0103       0.6580         1
# 8670        1   25                1      29.0000                   1            2               1      23927.0000              152.0000      238        6942                100.5336      38.3403              3.4467       0.6467         1
# 739         1   21                1       2.0000                   0            2               1      18317.0000              152.0000      147        5453                124.6054      52.1429              3.3591       0.6425         1
# 9693        1   25                1      21.0000                   1            2               1      19687.0000              152.0000      168        6942                117.1845      54.3155              2.8359       0.6406         1
# 19208       1   25                1      21.0000                   1            2               1      24215.0000              152.0000      189        6942                128.1217      48.2804              3.4882       0.6406         1

# %% [markdown]
# # Deploy

# %%
# saving the trained model
lgbm = LGBMClassifier(n_jobs=-1).fit(x_train, y_train)
pickle.dump(lgbm, open('data/lgbm.pkl', 'wb'))

# %% [markdown]
# ## Insurance All Class

# %%
import json
import pickle
import pandas as pd

class InsuranceAll (object):
    
    def __init__(self, df_test): 
        
       self.home='' 
        
    def data_cleaning (df_test)            
    
        # columns to lowercase
        df_test.columns = ['id', 'gender', 'age', 'driving_license', 'region_code',
                           'previously_insured', 'vehicle_age', 'vehicle_damage', 'annual_premium',
                           'policy_sales_channel', 'vintage']
        
        
        # drop id column
        df_test = df_test.drop('id', axis=1).copy()
        
        return df_test
            
    def encoding (df_test): 
        
    # label enconding
        df_test['gender'] = df_test['gender'].apply(lambda x: 0 if x == 'male' else 1).astype(int)
        df_test["vehicle_damage"] = df_test["vehicle_damage"].apply(lambda x: 0 if x == 'no' else 1).astype(int)
        
        # ordinal enconding
        df_test["vehicle_age"] = df_test["vehicle_age"].apply(lambda x: 0 if x == '< 1 year' else 1 if x == '1-2 year' else 2).astype(int)
        
        return df_test
    
    def feature_engineering (self, df_test): 
        
        # age damage
        age_damage = pd.DataFrame(df_test.groupby('age')['vehicle_damage'].sum()).reset_index().rename(columns={'vehicle_damage':'age_damage'})
        df_test = pd.merge(df_test, age_damage, how='left', on='age')
        
        # vintage annual premium
        df_test['vintage_annual_premium'] = (df_test['annual_premium']) / (df_test['vintage'])
        
        # age vintage
        df_test['age_vintage'] = (df_test['age']*365) / (df_test['vintage'])
        
        # age_damage_premium
        df_test['age_damage_premium'] = (df_test['annual_premium']) / (df_test['age_damage'])
        
        return df_test
        
    def get_prediction(self, model, original_data, df_test):
        # predictions
        pred = model.predict_proba(df_test)
        original_data['prediction'] = pred[:,1]
        
        # sort values 
        original_data = original_data.sort_values('prediction',ascending=False)
        
        return original_data.to_json(orient = 'records', date_format='iso')

# %% [markdown]
# ## API Handler

# %%
import pickle
import pandas as pd
from flask import Flask, request, Response
from insuranceall.InsuranceAll import InsuranceAll

model = pickle.load(open('/home/andre/Insync/pa004_health_insurance_cross_sell/data/lgbm.pkl', 'rb'))

app = Flask(__name__)
@app.route('/InsuranceAll/predict', methods=['POST'])

def insurance_all_predict():
    test_json = request.get_json()
    
    if test_json:
        if isinstance(test_json,dict):
            df_test = pd.DataFrame(test_json,index=[0])
        else:
            df_test = pd.DataFrame(test_json,columns=test_json[0].keys())
               
        pipeline = InsuranceAll()
        df = df_test.copy()
        df = pipeline.data_cleaning(df)
        df = pipeline.encoding(df)
        df = pipeline.feature_engieneering(df)
        df_final = pipeline.get_prediction(model,df_test, df)
        
        return df_final
    
    else:
        return Response('{}', status=200, mimetype='application/json')

    
if __name__ == '__main__':
    app.run('0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
